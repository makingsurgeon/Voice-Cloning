# %%
import os
import numpy as np
import librosa
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical

# %%
# Define paths and parameters
DATASET_PATH = "/Users/zihuiouyang/Downloads/LA/ASVspoof2019_LA_train/flac"
LABEL_FILE_PATH = "/Users/zihuiouyang/Downloads/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.train.trn.txt"
NUM_CLASSES = 2  # Number of classes (bonafide and spoof)
SAMPLE_RATE = 16000  # Sample rate of your audio files
DURATION = 5  # Duration of audio clips in seconds
N_MELS = 128  # Number of Mel frequency bins

# %%
import fnmatch
import os

# %%
a = []
for filename in os.listdir('/Users/zihuiouyang/Downloads/cv-corpus-15.0-delta-2023-09-08/en/clips'):
    if fnmatch.fnmatch(filename, '*.flac'):
        a.append(filename)

# %%
import random
a1 = random.sample(a,22800)

# %%
labels = {}
for i in range(len(a1)):
    file_name = a1[i]
    label = 1
    labels[file_name] = label

# %%
labels
# Out:
# {'common_voice_en_38050461.flac': 1,
#  'common_voice_en_38320068.flac': 1,
#  'common_voice_en_38153365.flac': 1,
#  'common_voice_en_38164709.flac': 1,
#  'common_voice_en_38311226.flac': 1,
#  'common_voice_en_38111813.flac': 1,
#  'common_voice_en_38126948.flac': 1,
#  'common_voice_en_38035524.flac': 1,
#  'common_voice_en_38461130.flac': 1,
#  'common_voice_en_38164707.flac': 1,
#  'common_voice_en_38050444.flac': 1,
#  'common_voice_en_38267103.flac': 1,
#  'common_voice_en_38291679.flac': 1,
#  'common_voice_en_38308150.flac': 1,
#  'common_voice_en_38356661.flac': 1,
#  'common_voice_en_38231849.flac': 1,
#  'common_voice_en_38237658.flac': 1,
#  'common_voice_en_38450948.flac': 1,
#  'common_voice_en_38421029.flac': 1,
#  'common_voice_en_38270701.flac': 1,
#  'common_voice_en_38315397.flac': 1,
#  'common_voice_en_38420851.flac': 1,
#  'common_voice_en_38052609.flac': 1,
#  'common_voice_en_38081170.flac': 1,
#  'common_voice_en_38341421.flac': 1,
#  'common_voice_en_38251564.flac': 1,
#  'common_voice_en_38235167.flac': 1,
#  'common_voice_en_38353270.flac': 1,
#  'common_voice_en_38114657.flac': 1,
#  'common_voice_en_38352517.flac': 1,
#  'common_voice_en_38336910.flac': 1,
#  'common_voice_en_38449269.flac': 1,
#  'common_voice_en_38449642.flac': 1,
#  'common_voice_en_38158909.flac': 1,
#  'common_voice_en_38280573.flac': 1,
#  'common_voice_en_38470640.flac': 1,
#  'common_voice_en_38249120.flac': 1,
#  'common_voice_en_38424495.flac': 1,
#  'common_voice_en_38099562.flac': 1,
#  'common_voice_en_38160766.flac': 1,
#  'common_voice_en_38025487.flac': 1,
#  'common_voice_en_38419203.flac': 1,
#  'common_voice_en_38035600.flac': 1,
#  'common_voice_en_38276894.flac': 1,
#  'common_voice_en_38448573.flac': 1,
#  'common_voice_en_38287884.flac': 1,
#  'common_voice_en_38403230.flac': 1,
#  'common_voice_en_38293565.flac': 1,
#  'common_voice_en_38286853.flac': 1,
#  'common_voice_en_38413902.flac': 1,
#  'common_voice_en_38395556.flac': 1,
#  'common_voice_en_38328053.flac': 1,
#  'common_voice_en_38362179.flac': 1,
#  'common_voice_en_38145729.flac': 1,
#  'common_voice_en_38052536.flac': 1,
#  'common_voice_en_38421257.flac': 1,
#  'common_voice_en_38028907.flac': 1,
#  'common_voice_en_38398164.flac': 1,
#  'common_voice_en_38320891.flac': 1,
#  'common_voice_en_38256252.flac': 1,
#  'common_voice_en_38337136.flac': 1,
#  'common_voice_en_38420896.flac': 1,
#  'common_voice_en_38143795.flac': 1,
#  'common_voice_en_38029499.flac': 1,
#  'common_voice_en_38147976.flac': 1,
#  'common_voice_en_38403967.flac': 1,
#  'common_voice_en_38328020.flac': 1,
#  'common_voice_en_38100300.flac': 1,
#  'common_voice_en_38358426.flac': 1,
#  'common_voice_en_38421498.flac': 1,
#  'common_voice_en_38057750.flac': 1,
#  'common_voice_en_38267118.flac': 1,
#  'common_voice_en_38331225.flac': 1,
#  'common_voice_en_38235364.flac': 1,
#  'common_voice_en_38176675.flac': 1,
#  'common_voice_en_38402703.flac': 1,
#  'common_voice_en_38164544.flac': 1,
#  'common_voice_en_38421694.flac': 1,
#  'common_voice_en_38371804.flac': 1,
#  'common_voice_en_38419371.flac': 1,
#  'common_voice_en_38293145.flac': 1,
#  'common_voice_en_38080802.flac': 1,
#  'common_voice_en_38079027.flac': 1,
#  'common_voice_en_38067941.flac': 1,
#  'common_voice_en_38052607.flac': 1,
#  'common_voice_en_38355017.flac': 1,
#  'common_voice_en_38035562.flac': 1,
#  'common_voice_en_38371828.flac': 1,
#  'common_voice_en_38376969.flac': 1,
#  'common_voice_en_38265152.flac': 1,
#  'common_voice_en_38302044.flac': 1,
#  'common_voice_en_38056145.flac': 1,
#  'common_voice_en_38237576.flac': 1,
#  'common_voice_en_38471604.flac': 1,
#  'common_voice_en_38337104.flac': 1,
#  'common_voice_en_38346625.flac': 1,
#  'common_voice_en_38038510.flac': 1,
#  'common_voice_en_38099156.flac': 1,
#  'common_voice_en_38029397.flac': 1,
#  'common_voice_en_38352518.flac': 1,
#  'common_voice_en_38081267.flac': 1,
#  'common_voice_en_38267463.flac': 1,
#  'common_voice_en_38254725.flac': 1,
#  'common_voice_en_38291741.flac': 1,
#  'common_voice_en_38035512.flac': 1,
#  'common_voice_en_38053499.flac': 1,
#  'common_voice_en_38233254.flac': 1,
#  'common_voice_en_38450932.flac': 1,
#  'common_voice_en_38038436.flac': 1,
#  'common_voice_en_38328314.flac': 1,
#  'common_voice_en_38026642.flac': 1,
#  'common_voice_en_38355722.flac': 1,
#  'common_voice_en_38404640.flac': 1,
#  'common_voice_en_38376801.flac': 1,
#  'common_voice_en_38132073.flac': 1,
#  'common_voice_en_38421017.flac': 1,
#  'common_voice_en_38156209.flac': 1,
#  'common_voice_en_38296047.flac': 1,
#  'common_voice_en_38358865.flac': 1,
#  'common_voice_en_38358011.flac': 1,
#  'common_voice_en_38304635.flac': 1,
#  'common_voice_en_38189488.flac': 1,
#  'common_voice_en_38346721.flac': 1,
#  'common_voice_en_38153349.flac': 1,
#  'common_voice_en_38116197.flac': 1,
#  'common_voice_en_38099480.flac': 1,
#  'common_voice_en_38143584.flac': 1,
#  'common_voice_en_38371264.flac': 1,
#  'common_voice_en_38029761.flac': 1,
#  'common_voice_en_38032344.flac': 1,
#  'common_voice_en_38359043.flac': 1,
#  'common_voice_en_38340309.flac': 1,
#  'common_voice_en_38267113.flac': 1,
#  'common_voice_en_38099821.flac': 1,
#  'common_voice_en_38235329.flac': 1,
#  'common_voice_en_38270527.flac': 1,
#  'common_voice_en_38352512.flac': 1,
#  'common_voice_en_38394635.flac': 1,
#  'common_voice_en_38398662.flac': 1,
#  'common_voice_en_38028822.flac': 1,
#  'common_voice_en_38059411.flac': 1,
#  'common_voice_en_38346735.flac': 1,
#  'common_voice_en_38039921.flac': 1,
#  'common_voice_en_38052510.flac': 1,
#  'common_voice_en_38421318.flac': 1,
#  'common_voice_en_38165136.flac': 1,
#  'common_voice_en_38125204.flac': 1,
#  'common_voice_en_38415353.flac': 1,
#  'common_voice_en_38078923.flac': 1,
#  'common_voice_en_38347105.flac': 1,
#  'common_voice_en_38403955.flac': 1,
#  'common_voice_en_38153355.flac': 1,
#  'common_voice_en_38116475.flac': 1,
#  'common_voice_en_38032373.flac': 1,
#  'common_voice_en_38376475.flac': 1,
#  'common_voice_en_38472428.flac': 1,
#  'common_voice_en_38398245.flac': 1,
#  'common_voice_en_38089934.flac': 1,
#  'common_voice_en_38145924.flac': 1,
#  'common_voice_en_38058817.flac': 1,
#  'common_voice_en_38311698.flac': 1,
#  'common_voice_en_38287886.flac': 1,
#  'common_voice_en_38129704.flac': 1,
#  'common_voice_en_38278544.flac': 1,
#  'common_voice_en_38273650.flac': 1,
#  'common_voice_en_38316453.flac': 1,
#  'common_voice_en_38057123.flac': 1,
#  'common_voice_en_38080251.flac': 1,
#  'common_voice_en_38027785.flac': 1,
#  'common_voice_en_38176558.flac': 1,
#  'common_voice_en_38214762.flac': 1,
#  'common_voice_en_38076153.flac': 1,
#  'common_voice_en_38235102.flac': 1,
#  'common_voice_en_38357326.flac': 1,
#  'common_voice_en_38349512.flac': 1,
#  'common_voice_en_38127377.flac': 1,
#  'common_voice_en_38251824.flac': 1,
#  'common_voice_en_38358458.flac': 1,
#  'common_voice_en_38030659.flac': 1,
#  'common_voice_en_38265381.flac': 1,
#  'common_voice_en_38357841.flac': 1,
#  'common_voice_en_38166551.flac': 1,
#  'common_voice_en_38394964.flac': 1,
#  'common_voice_en_38050313.flac': 1,
#  'common_voice_en_38398673.flac': 1,
#  'common_voice_en_38449393.flac': 1,
#  'common_voice_en_38266191.flac': 1,
#  'common_voice_en_38426950.flac': 1,
#  'common_voice_en_38265151.flac': 1,
#  'common_voice_en_38439599.flac': 1,
#  'common_voice_en_38410685.flac': 1,
#  'common_voice_en_38081767.flac': 1,
#  'common_voice_en_38400807.flac': 1,
#  'common_voice_en_38403834.flac': 1,
#  'common_voice_en_38109187.flac': 1,
#  'common_voice_en_38145230.flac': 1,
#  'common_voice_en_38401046.flac': 1,
#  'common_voice_en_38297305.flac': 1,
#  'common_voice_en_38310341.flac': 1,
#  'common_voice_en_38156000.flac': 1,
#  'common_voice_en_38358354.flac': 1,
#  'common_voice_en_38471705.flac': 1,
#  'common_voice_en_38178202.flac': 1,
#  'common_voice_en_38348365.flac': 1,
#  'common_voice_en_38310277.flac': 1,
#  'common_voice_en_38352844.flac': 1,
#  'common_voice_en_38337330.flac': 1,
#  'common_voice_en_38237654.flac': 1,
#  'common_voice_en_38415079.flac': 1,
#  'common_voice_en_38080840.flac': 1,
#  'common_voice_en_38143777.flac': 1,
#  'common_voice_en_38035502.flac': 1,
#  'common_voice_en_38265140.flac': 1,
#  'common_voice_en_38233387.flac': 1,
#  'common_voice_en_38328716.flac': 1,
#  'common_voice_en_38313642.flac': 1,
#  'common_voice_en_38081801.flac': 1,
#  'common_voice_en_38114831.flac': 1,
#  'common_voice_en_38201493.flac': 1,
#  'common_voice_en_38255284.flac': 1,
#  'common_voice_en_38358446.flac': 1,
#  'common_voice_en_38115961.flac': 1,
#  'common_voice_en_38426717.flac': 1,
#  'common_voice_en_38091955.flac': 1,
#  'common_voice_en_38034091.flac': 1,
#  'common_voice_en_38087748.flac': 1,
#  'common_voice_en_38032498.flac': 1,
#  'common_voice_en_38377224.flac': 1,
#  'common_voice_en_38081512.flac': 1,
#  'common_voice_en_38343430.flac': 1,
#  'common_voice_en_38439121.flac': 1,
#  'common_voice_en_38255273.flac': 1,
#  'common_voice_en_38444628.flac': 1,
#  'common_voice_en_38124696.flac': 1,
#  'common_voice_en_38162301.flac': 1,
#  'common_voice_en_38081414.flac': 1,
#  'common_voice_en_38218298.flac': 1,
#  'common_voice_en_38487326.flac': 1,
#  'common_voice_en_38089911.flac': 1,
#  'common_voice_en_38164202.flac': 1,
#  'common_voice_en_38181434.flac': 1,
#  'common_voice_en_38026725.flac': 1,
#  'common_voice_en_38037325.flac': 1,
#  'common_voice_en_38270738.flac': 1,
#  'common_voice_en_38080065.flac': 1,
#  'common_voice_en_38316403.flac': 1,
#  'common_voice_en_38354229.flac': 1,
#  'common_voice_en_38329223.flac': 1,
#  'common_voice_en_38062927.flac': 1,
#  'common_voice_en_38439675.flac': 1,
#  'common_voice_en_38111890.flac': 1,
#  'common_voice_en_38165195.flac': 1,
#  'common_voice_en_38382485.flac': 1,
#  'common_voice_en_38314137.flac': 1,
#  'common_voice_en_38081215.flac': 1,
#  'common_voice_en_38125106.flac': 1,
#  'common_voice_en_38356479.flac': 1,
#  'common_voice_en_38235129.flac': 1,
#  'common_voice_en_38294528.flac': 1,
#  'common_voice_en_38136186.flac': 1,
#  'common_voice_en_38356333.flac': 1,
#  'common_voice_en_38029027.flac': 1,
#  'common_voice_en_38291026.flac': 1,
#  'common_voice_en_38348863.flac': 1,
#  'common_voice_en_38306105.flac': 1,
#  'common_voice_en_38419596.flac': 1,
#  'common_voice_en_38034453.flac': 1,
#  'common_voice_en_38449234.flac': 1,
#  'common_voice_en_38033904.flac': 1,
#  'common_voice_en_38444657.flac': 1,
#  'common_voice_en_38248469.flac': 1,
#  'common_voice_en_38033955.flac': 1,
#  'common_voice_en_38111816.flac': 1,
#  'common_voice_en_38251618.flac': 1,
#  'common_voice_en_38330794.flac': 1,
#  'common_voice_en_38116538.flac': 1,
#  'common_voice_en_38392310.flac': 1,
#  'common_voice_en_38295376.flac': 1,
#  'common_voice_en_38346729.flac': 1,
#  'common_voice_en_38069697.flac': 1,
#  'common_voice_en_38331335.flac': 1,
#  'common_voice_en_38026410.flac': 1,
#  'common_voice_en_38079033.flac': 1,
#  'common_voice_en_38328019.flac': 1,
#  'common_voice_en_38081892.flac': 1,
#  'common_voice_en_38099583.flac': 1,
#  'common_voice_en_38166086.flac': 1,
#  'common_voice_en_38291646.flac': 1,
#  'common_voice_en_38235247.flac': 1,
#  'common_voice_en_38300017.flac': 1,
#  'common_voice_en_38471791.flac': 1,
#  'common_voice_en_38341466.flac': 1,
#  'common_voice_en_38235268.flac': 1,
#  'common_voice_en_38471823.flac': 1,
#  'common_voice_en_38382456.flac': 1,
#  'common_voice_en_38080083.flac': 1,
#  'common_voice_en_38153207.flac': 1,
#  'common_voice_en_38328179.flac': 1,
#  'common_voice_en_38153991.flac': 1,
#  'common_voice_en_38419430.flac': 1,
#  'common_voice_en_38400493.flac': 1,
#  'common_voice_en_38450983.flac': 1,
#  'common_voice_en_38349078.flac': 1,
#  'common_voice_en_38081393.flac': 1,
#  'common_voice_en_38251636.flac': 1,
#  'common_voice_en_38346586.flac': 1,
#  'common_voice_en_38419855.flac': 1,
#  'common_voice_en_38318730.flac': 1,
#  'common_voice_en_38349071.flac': 1,
#  'common_voice_en_38099634.flac': 1,
#  'common_voice_en_38027437.flac': 1,
#  'common_voice_en_38300019.flac': 1,
#  'common_voice_en_38449112.flac': 1,
#  'common_voice_en_38161393.flac': 1,
#  'common_voice_en_38026636.flac': 1,
#  'common_voice_en_38376800.flac': 1,
#  'common_voice_en_38129617.flac': 1,
#  'common_voice_en_38153194.flac': 1,
#  'common_voice_en_38242136.flac': 1,
#  'common_voice_en_38122225.flac': 1,
#  'common_voice_en_38028829.flac': 1,
#  'common_voice_en_38255281.flac': 1,
#  'common_voice_en_38346510.flac': 1,
#  'common_voice_en_38144106.flac': 1,
#  'common_voice_en_38158939.flac': 1,
#  'common_voice_en_38144769.flac': 1,
#  'common_voice_en_38099704.flac': 1,
#  'common_voice_en_38025428.flac': 1,
#  'common_voice_en_38358770.flac': 1,
#  'common_voice_en_38090298.flac': 1,
#  'common_voice_en_38449475.flac': 1,
#  'common_voice_en_38122511.flac': 1,
#  'common_voice_en_38125267.flac': 1,
#  'common_voice_en_38027303.flac': 1,
#  'common_voice_en_38033634.flac': 1,
#  'common_voice_en_38191859.flac': 1,
#  'common_voice_en_38164389.flac': 1,
#  'common_voice_en_38069815.flac': 1,
#  'common_voice_en_38043587.flac': 1,
#  'common_voice_en_38235420.flac': 1,
#  'common_voice_en_38403275.flac': 1,
#  'common_voice_en_38153148.flac': 1,
#  'common_voice_en_38129646.flac': 1,
#  'common_voice_en_38111635.flac': 1,
#  'common_voice_en_38270715.flac': 1,
#  'common_voice_en_38342968.flac': 1,
#  'common_voice_en_38156187.flac': 1,
#  'common_voice_en_38111945.flac': 1,
#  'common_voice_en_38136259.flac': 1,
#  'common_voice_en_38099646.flac': 1,
#  'common_voice_en_38359609.flac': 1,
#  'common_voice_en_38439751.flac': 1,
#  'common_voice_en_38080958.flac': 1,
#  'common_voice_en_38334677.flac': 1,
#  'common_voice_en_38025215.flac': 1,
#  'common_voice_en_38421673.flac': 1,
#  'common_voice_en_38062976.flac': 1,
#  'common_voice_en_38329221.flac': 1,
#  'common_voice_en_38116277.flac': 1,
#  'common_voice_en_38039397.flac': 1,
#  'common_voice_en_38371326.flac': 1,
#  'common_voice_en_38396214.flac': 1,
#  'common_voice_en_38144071.flac': 1,
#  'common_voice_en_38100173.flac': 1,
#  'common_voice_en_38397218.flac': 1,
#  'common_voice_en_38419254.flac': 1,
#  'common_voice_en_38164645.flac': 1,
#  'common_voice_en_38314010.flac': 1,
#  'common_voice_en_38414913.flac': 1,
#  'common_voice_en_38047481.flac': 1,
#  'common_voice_en_38255333.flac': 1,
#  'common_voice_en_38132865.flac': 1,
#  'common_voice_en_38084579.flac': 1,
#  'common_voice_en_38348366.flac': 1,
#  'common_voice_en_38127495.flac': 1,
#  'common_voice_en_38284643.flac': 1,
#  'common_voice_en_38056207.flac': 1,
#  'common_voice_en_38342978.flac': 1,
#  'common_voice_en_38404712.flac': 1,
#  'common_voice_en_38220487.flac': 1,
#  'common_voice_en_38125071.flac': 1,
#  'common_voice_en_38026298.flac': 1,
#  'common_voice_en_38124887.flac': 1,
#  'common_voice_en_38321623.flac': 1,
#  'common_voice_en_38081287.flac': 1,
#  'common_voice_en_38041794.flac': 1,
#  'common_voice_en_38417185.flac': 1,
#  'common_voice_en_38182471.flac': 1,
#  'common_voice_en_38346778.flac': 1,
#  'common_voice_en_38331479.flac': 1,
#  'common_voice_en_38031639.flac': 1,
#  'common_voice_en_38358562.flac': 1,
#  'common_voice_en_38118474.flac': 1,
#  'common_voice_en_38182485.flac': 1,
#  'common_voice_en_38025745.flac': 1,
#  'common_voice_en_38038474.flac': 1,
#  'common_voice_en_38165954.flac': 1,
#  'common_voice_en_38315396.flac': 1,
#  'common_voice_en_38147865.flac': 1,
#  'common_voice_en_38052554.flac': 1,
#  'common_voice_en_38095507.flac': 1,
#  'common_voice_en_38415379.flac': 1,
#  'common_voice_en_38359189.flac': 1,
#  'common_voice_en_38025778.flac': 1,
#  'common_voice_en_38464809.flac': 1,
#  'common_voice_en_38127174.flac': 1,
#  'common_voice_en_38047537.flac': 1,
#  'common_voice_en_38099300.flac': 1,
#  'common_voice_en_38159680.flac': 1,
#  'common_voice_en_38449444.flac': 1,
#  'common_voice_en_38337583.flac': 1,
#  'common_voice_en_38235189.flac': 1,
#  'common_voice_en_38047524.flac': 1,
#  'common_voice_en_38026670.flac': 1,
#  'common_voice_en_38339669.flac': 1,
#  'common_voice_en_38329439.flac': 1,
#  'common_voice_en_38424836.flac': 1,
#  'common_voice_en_38425003.flac': 1,
#  'common_voice_en_38099635.flac': 1,
#  'common_voice_en_38027330.flac': 1,
#  'common_voice_en_38450866.flac': 1,
#  'common_voice_en_38034081.flac': 1,
#  'common_voice_en_38150653.flac': 1,
#  'common_voice_en_38249383.flac': 1,
#  'common_voice_en_38035569.flac': 1,
#  'common_voice_en_38149692.flac': 1,
#  'common_voice_en_38032497.flac': 1,
#  'common_voice_en_38116557.flac': 1,
#  'common_voice_en_38099383.flac': 1,
#  'common_voice_en_38265155.flac': 1,
#  'common_voice_en_38355651.flac': 1,
#  'common_voice_en_38164808.flac': 1,
#  'common_voice_en_38398171.flac': 1,
#  'common_voice_en_38471690.flac': 1,
#  'common_voice_en_38334776.flac': 1,
#  'common_voice_en_38306134.flac': 1,
#  'common_voice_en_38032348.flac': 1,
#  'common_voice_en_38404678.flac': 1,
#  'common_voice_en_38096195.flac': 1,
#  'common_voice_en_38138181.flac': 1,
#  'common_voice_en_38404651.flac': 1,
#  'common_voice_en_38316561.flac': 1,
#  'common_voice_en_38091830.flac': 1,
#  'common_voice_en_38421171.flac': 1,
#  'common_voice_en_38116490.flac': 1,
#  'common_voice_en_38126293.flac': 1,
#  'common_voice_en_38155980.flac': 1,
#  'common_voice_en_38275055.flac': 1,
#  'common_voice_en_38182182.flac': 1,
#  'common_voice_en_38275871.flac': 1,
#  'common_voice_en_38358452.flac': 1,
#  'common_voice_en_38301031.flac': 1,
#  'common_voice_en_38029048.flac': 1,
#  'common_voice_en_38069702.flac': 1,
#  'common_voice_en_38081883.flac': 1,
#  'common_voice_en_38254092.flac': 1,
#  'common_voice_en_38451130.flac': 1,
#  'common_voice_en_38133659.flac': 1,
#  'common_voice_en_38124758.flac': 1,
#  'common_voice_en_38341739.flac': 1,
#  'common_voice_en_38300315.flac': 1,
#  'common_voice_en_38356649.flac': 1,
#  'common_voice_en_38287178.flac': 1,
#  'common_voice_en_38029207.flac': 1,
#  'common_voice_en_38320079.flac': 1,
#  'common_voice_en_38281271.flac': 1,
#  'common_voice_en_38237683.flac': 1,
#  'common_voice_en_38053485.flac': 1,
#  'common_voice_en_38057585.flac': 1,
#  'common_voice_en_38358988.flac': 1,
#  'common_voice_en_38450740.flac': 1,
#  'common_voice_en_38358374.flac': 1,
#  'common_voice_en_38284548.flac': 1,
#  'common_voice_en_38382566.flac': 1,
#  'common_voice_en_38122547.flac': 1,
#  'common_voice_en_38419475.flac': 1,
#  'common_voice_en_38311618.flac': 1,
#  'common_voice_en_38450999.flac': 1,
#  'common_voice_en_38328114.flac': 1,
#  'common_voice_en_38140145.flac': 1,
#  'common_voice_en_38213175.flac': 1,
#  'common_voice_en_38296377.flac': 1,
#  'common_voice_en_38081646.flac': 1,
#  'common_voice_en_38116066.flac': 1,
#  'common_voice_en_38170654.flac': 1,
#  'common_voice_en_38343369.flac': 1,
#  'common_voice_en_38390344.flac': 1,
#  'common_voice_en_38450640.flac': 1,
#  'common_voice_en_38047539.flac': 1,
#  'common_voice_en_38126203.flac': 1,
#  'common_voice_en_38122587.flac': 1,
#  'common_voice_en_38195330.flac': 1,
#  'common_voice_en_38090304.flac': 1,
#  'common_voice_en_38266242.flac': 1,
#  'common_voice_en_38132094.flac': 1,
#  'common_voice_en_38275788.flac': 1,
#  'common_voice_en_38034358.flac': 1,
#  'common_voice_en_38080047.flac': 1,
#  'common_voice_en_38267453.flac': 1,
#  'common_voice_en_38080127.flac': 1,
#  'common_voice_en_38295396.flac': 1,
#  'common_voice_en_38108847.flac': 1,
#  'common_voice_en_38361653.flac': 1,
#  'common_voice_en_38029000.flac': 1,
#  'common_voice_en_38145710.flac': 1,
#  'common_voice_en_38424415.flac': 1,
#  'common_voice_en_38070337.flac': 1,
#  'common_voice_en_38420713.flac': 1,
#  'common_voice_en_38291813.flac': 1,
#  'common_voice_en_38056165.flac': 1,
#  'common_voice_en_38057573.flac': 1,
#  'common_voice_en_38199703.flac': 1,
#  'common_voice_en_38376872.flac': 1,
#  'common_voice_en_38282302.flac': 1,
#  'common_voice_en_38354990.flac': 1,
#  'common_voice_en_38419563.flac': 1,
#  'common_voice_en_38350832.flac': 1,
#  'common_voice_en_38050716.flac': 1,
#  'common_voice_en_38265541.flac': 1,
#  'common_voice_en_38053465.flac': 1,
#  'common_voice_en_38155740.flac': 1,
#  'common_voice_en_38455658.flac': 1,
#  'common_voice_en_38448466.flac': 1,
#  'common_voice_en_38080046.flac': 1,
#  'common_voice_en_38081193.flac': 1,
#  'common_voice_en_38081376.flac': 1,
#  'common_voice_en_38078951.flac': 1,
#  'common_voice_en_38302177.flac': 1,
#  'common_voice_en_38283712.flac': 1,
#  'common_voice_en_38031649.flac': 1,
#  'common_voice_en_38450873.flac': 1,
#  'common_voice_en_38033564.flac': 1,
#  'common_voice_en_38133172.flac': 1,
#  'common_voice_en_38356668.flac': 1,
#  'common_voice_en_38337599.flac': 1,
#  'common_voice_en_38245624.flac': 1,
#  'common_voice_en_38154637.flac': 1,
#  'common_voice_en_38316492.flac': 1,
#  'common_voice_en_38165071.flac': 1,
#  'common_voice_en_38198360.flac': 1,
#  'common_voice_en_38450529.flac': 1,
#  'common_voice_en_38027720.flac': 1,
#  'common_voice_en_38272840.flac': 1,
#  'common_voice_en_38032387.flac': 1,
#  'common_voice_en_38366792.flac': 1,
#  'common_voice_en_38100323.flac': 1,
#  'common_voice_en_38414916.flac': 1,
#  'common_voice_en_38125951.flac': 1,
#  'common_voice_en_38487378.flac': 1,
#  'common_voice_en_38376839.flac': 1,
#  'common_voice_en_38267138.flac': 1,
#  'common_voice_en_38033609.flac': 1,
#  'common_voice_en_38359992.flac': 1,
#  'common_voice_en_38356215.flac': 1,
#  'common_voice_en_38365422.flac': 1,
#  'common_voice_en_38099396.flac': 1,
#  'common_voice_en_38487361.flac': 1,
#  'common_voice_en_38047372.flac': 1,
#  'common_voice_en_38289461.flac': 1,
#  'common_voice_en_38061972.flac': 1,
#  'common_voice_en_38118470.flac': 1,
#  'common_voice_en_38156230.flac': 1,
#  'common_voice_en_38328371.flac': 1,
#  'common_voice_en_38057104.flac': 1,
#  'common_voice_en_38027400.flac': 1,
#  'common_voice_en_38450783.flac': 1,
#  'common_voice_en_38084813.flac': 1,
#  'common_voice_en_38026766.flac': 1,
#  'common_voice_en_38136135.flac': 1,
#  'common_voice_en_38027034.flac': 1,
#  'common_voice_en_38052542.flac': 1,
#  'common_voice_en_38371377.flac': 1,
#  'common_voice_en_38328427.flac': 1,
#  'common_voice_en_38398447.flac': 1,
#  'common_voice_en_38047313.flac': 1,
#  'common_voice_en_38415067.flac': 1,
#  'common_voice_en_38362041.flac': 1,
#  'common_voice_en_38444406.flac': 1,
#  'common_voice_en_38396335.flac': 1,
#  'common_voice_en_38121593.flac': 1,
#  'common_voice_en_38280344.flac': 1,
#  'common_voice_en_38194775.flac': 1,
#  'common_voice_en_38125916.flac': 1,
#  'common_voice_en_38159695.flac': 1,
#  'common_voice_en_38031344.flac': 1,
#  'common_voice_en_38293645.flac': 1,
#  'common_voice_en_38116196.flac': 1,
#  'common_voice_en_38214637.flac': 1,
#  'common_voice_en_38165361.flac': 1,
#  'common_voice_en_38029598.flac': 1,
#  'common_voice_en_38308281.flac': 1,
#  'common_voice_en_38312012.flac': 1,
#  'common_voice_en_38419571.flac': 1,
#  'common_voice_en_38354217.flac': 1,
#  'common_voice_en_38376735.flac': 1,
#  'common_voice_en_38311198.flac': 1,
#  'common_voice_en_38122593.flac': 1,
#  'common_voice_en_38450915.flac': 1,
#  'common_voice_en_38334693.flac': 1,
#  'common_voice_en_38068699.flac': 1,
#  'common_voice_en_38398445.flac': 1,
#  'common_voice_en_38341793.flac': 1,
#  'common_voice_en_38330816.flac': 1,
#  'common_voice_en_38352566.flac': 1,
#  'common_voice_en_38395870.flac': 1,
#  'common_voice_en_38035646.flac': 1,
#  'common_voice_en_38266226.flac': 1,
#  'common_voice_en_38471932.flac': 1,
#  'common_voice_en_38366532.flac': 1,
#  'common_voice_en_38060736.flac': 1,
#  'common_voice_en_38394616.flac': 1,
#  'common_voice_en_38327979.flac': 1,
#  'common_voice_en_38038328.flac': 1,
#  'common_voice_en_38376995.flac': 1,
#  'common_voice_en_38418350.flac': 1,
#  'common_voice_en_38034416.flac': 1,
#  'common_voice_en_38266240.flac': 1,
#  'common_voice_en_38333256.flac': 1,
#  'common_voice_en_38124749.flac': 1,
#  'common_voice_en_38450930.flac': 1,
#  'common_voice_en_38448885.flac': 1,
#  'common_voice_en_38029385.flac': 1,
#  'common_voice_en_38395217.flac': 1,
#  'common_voice_en_38057722.flac': 1,
#  'common_voice_en_38076155.flac': 1,
#  'common_voice_en_38164846.flac': 1,
#  'common_voice_en_38398149.flac': 1,
#  'common_voice_en_38165440.flac': 1,
#  'common_voice_en_38361650.flac': 1,
#  'common_voice_en_38337343.flac': 1,
#  'common_voice_en_38028901.flac': 1,
#  'common_voice_en_38129591.flac': 1,
#  'common_voice_en_38242049.flac': 1,
#  'common_voice_en_38081731.flac': 1,
#  'common_voice_en_38165984.flac': 1,
#  'common_voice_en_38038086.flac': 1,
#  'common_voice_en_38153547.flac': 1,
#  'common_voice_en_38089783.flac': 1,
#  'common_voice_en_38025162.flac': 1,
#  'common_voice_en_38420034.flac': 1,
#  'common_voice_en_38221878.flac': 1,
#  'common_voice_en_38159681.flac': 1,
#  'common_voice_en_38124708.flac': 1,
#  'common_voice_en_38153614.flac': 1,
#  'common_voice_en_38099397.flac': 1,
#  'common_voice_en_38158913.flac': 1,
#  'common_voice_en_38091786.flac': 1,
#  'common_voice_en_38125117.flac': 1,
#  'common_voice_en_38371620.flac': 1,
#  'common_voice_en_38402962.flac': 1,
#  'common_voice_en_38394939.flac': 1,
#  'common_voice_en_38235303.flac': 1,
#  'common_voice_en_38286786.flac': 1,
#  'common_voice_en_38083298.flac': 1,
#  'common_voice_en_38300003.flac': 1,
#  'common_voice_en_38187065.flac': 1,
#  'common_voice_en_38111933.flac': 1,
#  'common_voice_en_38356566.flac': 1,
#  'common_voice_en_38099756.flac': 1,
#  'common_voice_en_38099666.flac': 1,
#  'common_voice_en_38220492.flac': 1,
#  'common_voice_en_38059209.flac': 1,
#  'common_voice_en_38077716.flac': 1,
#  'common_voice_en_38029473.flac': 1,
#  'common_voice_en_38116474.flac': 1,
#  'common_voice_en_38132948.flac': 1,
#  'common_voice_en_38159346.flac': 1,
#  'common_voice_en_38143778.flac': 1,
#  'common_voice_en_38296132.flac': 1,
#  'common_voice_en_38449259.flac': 1,
#  'common_voice_en_38472444.flac': 1,
#  'common_voice_en_38281206.flac': 1,
#  'common_voice_en_38235379.flac': 1,
#  'common_voice_en_38422631.flac': 1,
#  'common_voice_en_38029016.flac': 1,
#  'common_voice_en_38220506.flac': 1,
#  'common_voice_en_38449199.flac': 1,
#  'common_voice_en_38421592.flac': 1,
#  'common_voice_en_38266190.flac': 1,
#  'common_voice_en_38319206.flac': 1,
#  'common_voice_en_38403103.flac': 1,
#  'common_voice_en_38235426.flac': 1,
#  'common_voice_en_38321733.flac': 1,
#  'common_voice_en_38314172.flac': 1,
#  'common_voice_en_38156007.flac': 1,
#  'common_voice_en_38274883.flac': 1,
#  'common_voice_en_38421322.flac': 1,
#  'common_voice_en_38310864.flac': 1,
#  'common_voice_en_38099124.flac': 1,
#  'common_voice_en_38037626.flac': 1,
#  'common_voice_en_38311153.flac': 1,
#  'common_voice_en_38365304.flac': 1,
#  'common_voice_en_38035615.flac': 1,
#  'common_voice_en_38358228.flac': 1,
#  'common_voice_en_38096633.flac': 1,
#  'common_voice_en_38222342.flac': 1,
#  'common_voice_en_38403261.flac': 1,
#  'common_voice_en_38111804.flac': 1,
#  'common_voice_en_38313993.flac': 1,
#  'common_voice_en_38035552.flac': 1,
#  'common_voice_en_38334051.flac': 1,
#  'common_voice_en_38133988.flac': 1,
#  'common_voice_en_38034094.flac': 1,
#  'common_voice_en_38027641.flac': 1,
#  'common_voice_en_38033957.flac': 1,
#  'common_voice_en_38428272.flac': 1,
#  'common_voice_en_38345839.flac': 1,
#  'common_voice_en_38029124.flac': 1,
#  'common_voice_en_38403319.flac': 1,
#  'common_voice_en_38158820.flac': 1,
#  'common_voice_en_38377487.flac': 1,
#  'common_voice_en_38098894.flac': 1,
#  'common_voice_en_38178210.flac': 1,
#  'common_voice_en_38395599.flac': 1,
#  'common_voice_en_38098999.flac': 1,
#  'common_voice_en_38131835.flac': 1,
#  'common_voice_en_38308318.flac': 1,
#  'common_voice_en_38035712.flac': 1,
#  'common_voice_en_38030893.flac': 1,
#  'common_voice_en_38026911.flac': 1,
#  'common_voice_en_38155429.flac': 1,
#  'common_voice_en_38279088.flac': 1,
#  'common_voice_en_38229418.flac': 1,
#  'common_voice_en_38461231.flac': 1,
#  'common_voice_en_38173496.flac': 1,
#  'common_voice_en_38220551.flac': 1,
#  'common_voice_en_38361612.flac': 1,
#  'common_voice_en_38089916.flac': 1,
#  'common_voice_en_38159317.flac': 1,
#  'common_voice_en_38206999.flac': 1,
#  'common_voice_en_38177307.flac': 1,
#  'common_voice_en_38343408.flac': 1,
#  'common_voice_en_38422482.flac': 1,
#  'common_voice_en_38122355.flac': 1,
#  'common_voice_en_38267351.flac': 1,
#  'common_voice_en_38159282.flac': 1,
#  'common_voice_en_38272835.flac': 1,
#  'common_voice_en_38328155.flac': 1,
#  'common_voice_en_38317347.flac': 1,
#  'common_voice_en_38403131.flac': 1,
#  'common_voice_en_38304648.flac': 1,
#  'common_voice_en_38164879.flac': 1,
#  'common_voice_en_38146985.flac': 1,
#  'common_voice_en_38125272.flac': 1,
#  'common_voice_en_38164247.flac': 1,
#  'common_voice_en_38194986.flac': 1,
#  'common_voice_en_38349164.flac': 1,
#  'common_voice_en_38226056.flac': 1,
#  'common_voice_en_38153377.flac': 1,
#  'common_voice_en_38308133.flac': 1,
#  'common_voice_en_38180347.flac': 1,
#  'common_voice_en_38365430.flac': 1,
#  'common_voice_en_38220546.flac': 1,
#  'common_voice_en_38025823.flac': 1,
#  'common_voice_en_38149716.flac': 1,
#  'common_voice_en_38133107.flac': 1,
#  'common_voice_en_38421055.flac': 1,
#  'common_voice_en_38091974.flac': 1,
#  'common_voice_en_38403837.flac': 1,
#  'common_voice_en_38130539.flac': 1,
#  'common_voice_en_38366898.flac': 1,
#  'common_voice_en_38129660.flac': 1,
#  'common_voice_en_38026406.flac': 1,
#  'common_voice_en_38029075.flac': 1,
#  'common_voice_en_38353268.flac': 1,
#  'common_voice_en_38436501.flac': 1,
#  'common_voice_en_38062904.flac': 1,
#  'common_voice_en_38165350.flac': 1,
#  'common_voice_en_38165306.flac': 1,
#  'common_voice_en_38291796.flac': 1,
#  'common_voice_en_38355713.flac': 1,
#  'common_voice_en_38376765.flac': 1,
#  'common_voice_en_38346795.flac': 1,
#  'common_voice_en_38377608.flac': 1,
#  'common_voice_en_38405020.flac': 1,
#  'common_voice_en_38384949.flac': 1,
#  'common_voice_en_38130461.flac': 1,
#  'common_voice_en_38145897.flac': 1,
#  'common_voice_en_38153606.flac': 1,
#  'common_voice_en_38313256.flac': 1,
#  'common_voice_en_38153668.flac': 1,
#  'common_voice_en_38324145.flac': 1,
#  'common_voice_en_38025867.flac': 1,
#  'common_voice_en_38472152.flac': 1,
#  'common_voice_en_38371334.flac': 1,
#  'common_voice_en_38100294.flac': 1,
#  'common_voice_en_38040044.flac': 1,
#  'common_voice_en_38033433.flac': 1,
#  'common_voice_en_38057056.flac': 1,
#  'common_voice_en_38448384.flac': 1,
#  'common_voice_en_38099594.flac': 1,
#  'common_voice_en_38449137.flac': 1,
#  'common_voice_en_38400492.flac': 1,
#  'common_voice_en_38336602.flac': 1,
#  'common_voice_en_38341781.flac': 1,
#  'common_voice_en_38420842.flac': 1,
#  'common_voice_en_38251600.flac': 1,
#  'common_voice_en_38335983.flac': 1,
#  'common_voice_en_38359197.flac': 1,
#  'common_voice_en_38050460.flac': 1,
#  'common_voice_en_38178151.flac': 1,
#  'common_voice_en_38232000.flac': 1,
#  'common_voice_en_38034747.flac': 1,
#  'common_voice_en_38181431.flac': 1,
#  'common_voice_en_38124694.flac': 1,
#  'common_voice_en_38424781.flac': 1,
#  'common_voice_en_38056095.flac': 1,
#  'common_voice_en_38318763.flac': 1,
#  'common_voice_en_38291682.flac': 1,
#  'common_voice_en_38132188.flac': 1,
#  'common_voice_en_38419445.flac': 1,
#  'common_voice_en_38066754.flac': 1,
#  'common_voice_en_38178098.flac': 1,
#  'common_voice_en_38031623.flac': 1,
#  'common_voice_en_38143823.flac': 1,
#  'common_voice_en_38095462.flac': 1,
#  'common_voice_en_38352647.flac': 1,
#  'common_voice_en_38029097.flac': 1,
#  'common_voice_en_38403282.flac': 1,
#  'common_voice_en_38124889.flac': 1,
#  'common_voice_en_38089997.flac': 1,
#  'common_voice_en_38091976.flac': 1,
#  'common_voice_en_38182770.flac': 1,
#  'common_voice_en_38350635.flac': 1,
#  'common_voice_en_38266162.flac': 1,
#  'common_voice_en_38274930.flac': 1,
#  'common_voice_en_38057726.flac': 1,
#  'common_voice_en_38111500.flac': 1,
#  'common_voice_en_38218377.flac': 1,
#  'common_voice_en_38035551.flac': 1,
#  'common_voice_en_38037459.flac': 1,
#  'common_voice_en_38029287.flac': 1,
#  'common_voice_en_38331197.flac': 1,
#  'common_voice_en_38132417.flac': 1,
#  'common_voice_en_38025244.flac': 1,
#  'common_voice_en_38084582.flac': 1,
#  'common_voice_en_38366789.flac': 1,
#  'common_voice_en_38126072.flac': 1,
#  'common_voice_en_38430686.flac': 1,
#  'common_voice_en_38369037.flac': 1,
#  'common_voice_en_38026744.flac': 1,
#  'common_voice_en_38350590.flac': 1,
#  'common_voice_en_38124571.flac': 1,
#  'common_voice_en_38450601.flac': 1,
#  'common_voice_en_38080357.flac': 1,
#  'common_voice_en_38132128.flac': 1,
#  'common_voice_en_38035533.flac': 1,
#  'common_voice_en_38166122.flac': 1,
#  'common_voice_en_38414952.flac': 1,
#  'common_voice_en_38331361.flac': 1,
#  'common_voice_en_38358531.flac': 1,
#  'common_voice_en_38352628.flac': 1,
#  'common_voice_en_38026475.flac': 1,
#  'common_voice_en_38079787.flac': 1,
#  'common_voice_en_38449388.flac': 1,
#  'common_voice_en_38450801.flac': 1,
#  'common_voice_en_38116029.flac': 1,
#  'common_voice_en_38130541.flac': 1,
#  'common_voice_en_38428248.flac': 1,
#  'common_voice_en_38081565.flac': 1,
#  'common_voice_en_38077624.flac': 1,
#  'common_voice_en_38124149.flac': 1,
#  'common_voice_en_38400381.flac': 1,
#  'common_voice_en_38080514.flac': 1,
#  'common_voice_en_38034284.flac': 1,
#  'common_voice_en_38080037.flac': 1,
#  'common_voice_en_38079826.flac': 1,
#  'common_voice_en_38091943.flac': 1,
#  'common_voice_en_38358981.flac': 1,
#  'common_voice_en_38396221.flac': 1,
#  'common_voice_en_38334006.flac': 1,
#  'common_voice_en_38474080.flac': 1,
#  'common_voice_en_38293417.flac': 1,
#  'common_voice_en_38208717.flac': 1,
#  'common_voice_en_38198008.flac': 1,
#  'common_voice_en_38159374.flac': 1,
#  'common_voice_en_38087583.flac': 1,
#  'common_voice_en_38358871.flac': 1,
#  'common_voice_en_38145087.flac': 1,
#  'common_voice_en_38089957.flac': 1,
#  'common_voice_en_38027687.flac': 1,
#  'common_voice_en_38033529.flac': 1,
#  'common_voice_en_38031547.flac': 1,
#  'common_voice_en_38394607.flac': 1,
#  'common_voice_en_38059422.flac': 1,
#  'common_voice_en_38361654.flac': 1,
#  'common_voice_en_38091922.flac': 1,
#  'common_voice_en_38346367.flac': 1,
#  'common_voice_en_38237620.flac': 1,
#  'common_voice_en_38116510.flac': 1,
#  'common_voice_en_38081159.flac': 1,
#  'common_voice_en_38396300.flac': 1,
#  'common_voice_en_38030633.flac': 1,
#  'common_voice_en_38450741.flac': 1,
#  'common_voice_en_38398914.flac': 1,
#  'common_voice_en_38270720.flac': 1,
#  'common_voice_en_38325724.flac': 1,
#  'common_voice_en_38285064.flac': 1,
#  'common_voice_en_38415018.flac': 1,
#  'common_voice_en_38324165.flac': 1,
#  'common_voice_en_38111729.flac': 1,
#  'common_voice_en_38031606.flac': 1,
#  'common_voice_en_38125002.flac': 1,
#  'common_voice_en_38025236.flac': 1,
#  'common_voice_en_38050446.flac': 1,
#  'common_voice_en_38128258.flac': 1,
#  'common_voice_en_38061057.flac': 1,
#  'common_voice_en_38147864.flac': 1,
#  'common_voice_en_38081567.flac': 1,
#  'common_voice_en_38320477.flac': 1,
#  'common_voice_en_38420715.flac': 1,
#  'common_voice_en_38091802.flac': 1,
#  'common_voice_en_38348256.flac': 1,
#  'common_voice_en_38425006.flac': 1,
#  'common_voice_en_38166490.flac': 1,
#  'common_voice_en_38420600.flac': 1,
#  'common_voice_en_38403026.flac': 1,
#  'common_voice_en_38248496.flac': 1,
#  'common_voice_en_38124998.flac': 1,
#  'common_voice_en_38251709.flac': 1,
#  'common_voice_en_38160788.flac': 1,
#  'common_voice_en_38026687.flac': 1,
#  'common_voice_en_38339227.flac': 1,
#  'common_voice_en_38359204.flac': 1,
#  'common_voice_en_38159424.flac': 1,
#  'common_voice_en_38098919.flac': 1,
#  'common_voice_en_38091981.flac': 1,
#  'common_voice_en_38339725.flac': 1,
#  'common_voice_en_38357856.flac': 1,
#  'common_voice_en_38400698.flac': 1,
#  'common_voice_en_38096202.flac': 1,
#  'common_voice_en_38433900.flac': 1,
#  'common_voice_en_38122589.flac': 1,
#  'common_voice_en_38402768.flac': 1,
#  'common_voice_en_38401735.flac': 1,
#  'common_voice_en_38347118.flac': 1,
#  'common_voice_en_38398285.flac': 1,
#  'common_voice_en_38239642.flac': 1,
#  'common_voice_en_38291680.flac': 1,
#  'common_voice_en_38310316.flac': 1,
#  'common_voice_en_38396322.flac': 1,
#  'common_voice_en_38321172.flac': 1,
#  'common_voice_en_38318778.flac': 1,
#  'common_voice_en_38398234.flac': 1,
#  'common_voice_en_38361604.flac': 1,
#  'common_voice_en_38331319.flac': 1,
#  'common_voice_en_38445191.flac': 1,
#  'common_voice_en_38451020.flac': 1,
#  'common_voice_en_38079037.flac': 1,
#  'common_voice_en_38424392.flac': 1,
#  'common_voice_en_38026816.flac': 1,
#  'common_voice_en_38328150.flac': 1,
#  'common_voice_en_38101626.flac': 1,
#  'common_voice_en_38352433.flac': 1,
#  'common_voice_en_38116540.flac': 1,
#  'common_voice_en_38116096.flac': 1,
#  'common_voice_en_38325678.flac': 1,
#  'common_voice_en_38056232.flac': 1,
#  'common_voice_en_38164262.flac': 1,
#  'common_voice_en_38044282.flac': 1,
#  'common_voice_en_38318764.flac': 1,
#  'common_voice_en_38337617.flac': 1,
#  'common_voice_en_38026505.flac': 1,
#  'common_voice_en_38312013.flac': 1,
#  'common_voice_en_38081000.flac': 1,
#  'common_voice_en_38420714.flac': 1,
#  'common_voice_en_38332217.flac': 1,
#  'common_voice_en_38165904.flac': 1,
#  'common_voice_en_38099671.flac': 1,
#  'common_voice_en_38339092.flac': 1,
#  'common_voice_en_38122354.flac': 1,
#  'common_voice_en_38404693.flac': 1,
#  'common_voice_en_38068675.flac': 1,
#  'common_voice_en_38331350.flac': 1,
#  'common_voice_en_38211285.flac': 1,
#  'common_voice_en_38235309.flac': 1,
#  'common_voice_en_38235422.flac': 1,
#  'common_voice_en_38047478.flac': 1,
#  'common_voice_en_38162362.flac': 1,
#  'common_voice_en_38352347.flac': 1,
#  'common_voice_en_38139807.flac': 1,
#  'common_voice_en_38294817.flac': 1,
#  'common_voice_en_38293315.flac': 1,
#  'common_voice_en_38420699.flac': 1,
#  'common_voice_en_38404597.flac': 1,
#  'common_voice_en_38448233.flac': 1,
#  'common_voice_en_38286813.flac': 1,
#  'common_voice_en_38182177.flac': 1,
#  'common_voice_en_38089670.flac': 1,
#  'common_voice_en_38400277.flac': 1,
#  'common_voice_en_38235326.flac': 1,
#  'common_voice_en_38424527.flac': 1,
#  'common_voice_en_38031560.flac': 1,
#  'common_voice_en_38293242.flac': 1,
#  'common_voice_en_38025512.flac': 1,
#  'common_voice_en_38132071.flac': 1,
#  'common_voice_en_38039428.flac': 1,
#  'common_voice_en_38421675.flac': 1,
#  'common_voice_en_38229093.flac': 1,
#  'common_voice_en_38095510.flac': 1,
#  ...}

# %%
X = []
y = []

max_time_steps = 109  # Define the maximum time steps for your model

for file_name, label in labels.items():
    file_path = os.path.join("/Users/zihuiouyang/Downloads/cv-corpus-15.0-delta-2023-09-08/en/clips", file_name)

    # Load audio file using librosa
    audio, _ = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)

    # Extract Mel spectrogram using librosa
    mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=SAMPLE_RATE, n_mels=N_MELS)
    mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

    # Ensure all spectrograms have the same width (time steps)
    if mel_spectrogram.shape[1] < max_time_steps:
        mel_spectrogram = np.pad(mel_spectrogram, ((0, 0), (0, max_time_steps - mel_spectrogram.shape[1])), mode='constant')
    else:
        mel_spectrogram = mel_spectrogram[:, :max_time_steps]

    X.append(mel_spectrogram)
    y.append(label)

# %%
labels1 = {}
with open(LABEL_FILE_PATH, 'r') as label_file:
    lines = label_file.readlines()

for line in lines:
    parts = line.strip().split()
    file_name = parts[1]
    if parts[-1] == "bonafide":
        continue
    label = 0
    labels1[file_name] = label

# %%
max_time_steps = 109  # Define the maximum time steps for your model

for file_name, label in labels1.items():
    file_path = os.path.join(DATASET_PATH, file_name + ".flac")

    # Load audio file using librosa
    audio, _ = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)

    # Extract Mel spectrogram using librosa
    mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=SAMPLE_RATE, n_mels=N_MELS)
    mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

    # Ensure all spectrograms have the same width (time steps)
    if mel_spectrogram.shape[1] < max_time_steps:
        mel_spectrogram = np.pad(mel_spectrogram, ((0, 0), (0, max_time_steps - mel_spectrogram.shape[1])), mode='constant')
    else:
        mel_spectrogram = mel_spectrogram[:, :max_time_steps]

    X.append(mel_spectrogram)
    y.append(label)

# %%
X = np.array(X)
y = np.array(y)

# %%
y_encoded = to_categorical(y, NUM_CLASSES)

# %%
split_index = int(0.8 * len(X))

# %%
split_index
# Out:
# 36480

# %%
b = []
for i in range(45600):
    b.append(i)

# %%
b1 = random.sample(b,36480)

# %%
mask=np.full(len(b),False,dtype=bool)
mask[b1]=True

# %%
X_train, X_val = X[mask], X[~mask]
y_train, y_val = y_encoded[mask], y_encoded[~mask]

# %%
input_shape = (N_MELS, X_train.shape[2], 1)  # Input shape for CNN (height, width, channels)
model_input = Input(shape=input_shape)

# %%
x = Conv2D(32, kernel_size=(3, 3), activation='relu')(model_input)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
model_output = Dense(NUM_CLASSES, activation='softmax')(x)

# %%
model = Model(inputs=model_input, outputs=model_output)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=32, epochs=5, validation_data=(X_val, y_val))
# Out:
# Epoch 1/5
# 1140/1140 [==============================] - 30s 25ms/step - loss: 3.5447 - accuracy: 0.9248 - val_loss: 0.3213 - val_accuracy: 0.9658
# Epoch 2/5
# 1140/1140 [==============================] - 27s 24ms/step - loss: 0.1477 - accuracy: 0.9846 - val_loss: 0.2976 - val_accuracy: 0.9615
# Epoch 3/5
# 1140/1140 [==============================] - 28s 24ms/step - loss: 0.0855 - accuracy: 0.9901 - val_loss: 0.0400 - val_accuracy: 0.9951
# Epoch 4/5
# 1140/1140 [==============================] - 28s 24ms/step - loss: 0.0543 - accuracy: 0.9919 - val_loss: 0.0704 - val_accuracy: 0.9884
# Epoch 5/5
# 1140/1140 [==============================] - 27s 24ms/step - loss: 0.1916 - accuracy: 0.9889 - val_loss: 0.0397 - val_accuracy: 0.9958

# %%
model.save("/Users/zihuiouyang/Documents/audio_classifier.h5")
# Out:
# /Users/zihuiouyang/anaconda3/envs/coqui/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
TEST_DATASET_PATH = "./TestEvaluation"
MODEL_PATH = "/Users/zihuiouyang/Documents/audio_classifier.h5"  # Replace with the actual path to your saved model
SAMPLE_RATE = 16000
DURATION = 5
N_MELS = 128
MAX_TIME_STEPS = 109

# %%
from tensorflow.keras.models import load_model
model = load_model(MODEL_PATH)

# %%
X_test = []

test_files = os.listdir(TEST_DATASET_PATH)
for file_name in test_files:
    file_path = os.path.join(TEST_DATASET_PATH, file_name)

    # Load audio file using librosa
    audio, _ = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)

    # Extract Mel spectrogram using librosa
    mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=SAMPLE_RATE, n_mels=N_MELS)
    mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

    # Ensure all spectrograms have the same width (time steps)
    if mel_spectrogram.shape[1] < MAX_TIME_STEPS:
        mel_spectrogram = np.pad(mel_spectrogram, ((0, 0), (0, MAX_TIME_STEPS - mel_spectrogram.shape[1])), mode='constant')
    else:
        mel_spectrogram = mel_spectrogram[:, :MAX_TIME_STEPS]

    X_test.append(mel_spectrogram)

# Convert list to numpy array
X_test = np.array(X_test)

# Predict using the loaded model
y_pred = model.predict(X_test)

# Convert probabilities to predicted classes
y_pred_classes = np.argmax(y_pred, axis=1)

y_pred
# Out:
# 1/1 [==============================] - 0s 290ms/step
# array([[1.00000e+00, 0.00000e+00],
#        [1.00000e+00, 1.85649e-28],
#        [1.00000e+00, 0.00000e+00],
#        [1.00000e+00, 0.00000e+00],
#        [1.00000e+00, 0.00000e+00],
#        [1.00000e+00, 0.00000e+00],
#        [1.00000e+00, 0.00000e+00],
#        [1.00000e+00, 0.00000e+00],
#        [1.00000e+00, 0.00000e+00],
#        [1.00000e+00, 0.00000e+00]], dtype=float32)
